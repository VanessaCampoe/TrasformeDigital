# %% [markdown]
# ## Ferramentas

# %% [markdown]
# * Visual Studio Code
# * Jupyter Notebook
# * Anaconda (ecossistema de ferramentas)

# %% [markdown]
# ## Conceiutos  de IA

# %%
* 1950ÇIA Classica (inverno da IA)
* Warrwn McCulloch (Neurocientista)e Walter Pitts (TI (eletronica))em 1943
* Marchine Learning para Negocios (Funções/estatistica)
* marchine Learning é uma IA
* Redes Neurais (Big Data) - DataBricks
* Redes Neurais Convolucionais
* Marchine Learning é indicado para negocios (Ache fácil)
* Prever o valor de vendas : Marchine Learning Supervisiionado 
* Prver se o cliente vai  comprar (sim) (não) determinado produto 
* Disruptiva
* www.psul.com.br (paixão)
* Ache Fácil (Box ----- Pessoa1)
* Sistema de Recomandações - target (valor) = nota

# %% [markdown]
# ## Marchine Learning Supervisionado por Regressão (Sitema de reomendação)

# %% [markdown]
# ### A base para aprender o algoritimo KNN

# %% [markdown]
# ### Teorema de Pitagoras

# %% [markdown]
# - Samos
# - A soma dos quadrados dos catetos é igual ao quadrado da hipotenuza
#
# imagem

# %% [markdown]
# imagem

# %% [markdown]
# # Considerando o valor de a = 5 e b = 10  qual o valor de c (teorema de pitágoras)

# %%
import math

a = 5
b = 10

c = math.sqrt(a**2 + b**2)

print(c)
# Out:
# 11.180339887498949

# %% [markdown]
# ## EXTRA
# fórmulas matemáticas úteis :
#
# ---
#
# ### 📐 **Teorema de Pitágoras**
#
# [
# c = \sqrt{a^2 + b^2}
# ]
#
# ```python
# import math
# c = math.sqrt(a**2 + b**2)
# ```
#
# ---
#
# ### 🔺 **Área de um triângulo**
#
# [
# A = \frac{b \cdot h}{2}
# ]
#
# ```python
# A = (base * altura) / 2
# ```
#
# ---
#
# ### ⚪ **Área do círculo**
#
# [
# A = \pi r^2
# ]
#
# ```python
# import math
# A = math.pi * r**2
# ```
#
# ---
#
# ### 🔵 **Comprimento da circunferência**
#
# [
# C = 2 \pi r
# ]
#
# ```python
# C = 2 * math.pi * r
# ```
#
# ---
#
# ### 📦 **Volume de um cubo**
#
# [
# V = a^3
# ]
#
# ```python
# V = a**3
# ```
#
# ---
#
# ### 🧮 **Média aritmética**
#
# [
# \text{média} = \frac{x_1 + x_2 + \dots + x_n}{n}
# ]
#
# ```python
# media = sum(lista) / len(lista)
# ```
#
# ---
#
# ### 📊 **Fórmula de Bhaskara (equação do 2º grau)**
#
# [
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# ]
#
# ```python
# import math
#
# delta = b**2 - 4*a*c
# x1 = (-b + math.sqrt(delta)) / (2*a)
# x2 = (-b - math.sqrt(delta)) / (2*a)
# ```
#
# ---
#
# ### 📈 **Porcentagem**
#
# [
# \text{valor} = \frac{p}{100} \cdot total
# ]
#
# ```python
# valor = (p / 100) * total
# ```
#
# ---

# %% [markdown]
# ### Distancia Euclidiana
# ligando

# %% [markdown]
# ### Scikitlearn
