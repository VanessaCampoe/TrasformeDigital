# %%
! pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ------------------ --------------------- 5.8/12.3 MB 50.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 51.5 MB/s  0:00:00
# ...

# %%
import numpy as np

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.2 MB 7.5 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.2 MB 7.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.2 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 5.2 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
! pip install scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.0 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.0 MB 3.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.0 MB 3.4 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.0 MB 3.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 3.4 MB/s eta 0:00:01
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Dados de treino
# x fitus caracteristicas
# y rotulos

# %%
X = np.array(
    [ 
              [150,7],[170,8],[140,7],[130,3],[120,2],[110,3]
    ]
)

# %%
y = np.array(
    [
        'Maça', 'Maça', 'Maça','Laranja', 'Laranja','Laranja'
    ]
)

# %%
# Classificando...
novo_dado = np.array([[145, 6]])
pred = knn.predict(novo_dado)
print(f"É uma: Maçã")
# Out:
# É uma: Maçã

# %%
knn = KNeighborsClassifier(
  n_neighbors=3
)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
red = knn.predict(novo_dado)
print(f"É uma: Maçã")
# Out:
# É uma: Maçã
